# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing data

# %%
# Path assignment
path = r'C:\Users\nodnarb\Documents\IC Basket Analysis'

# %%
# Import orders products prior dataframe
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
# Orders prior dimension check
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Import cleaned orders dataframe
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_time  days_since_prior_order
# 0                   2           8                     0.0
# 1                   3           7                    15.0
# 2                   3          12                    21.0
# 3                   4           7                    29.0
# 4                   4          15                    28.0

# %% [markdown]
# #### Merging orders and orders products prior

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32434484       3421081     3421081   2977660   206209            13
# 32434485       3421081     3421081   2977660   206209            13
# 32434486       3421081     3421081   2977660   206209            13
# 32434487       3421081     3421081   2977660   206209            13
# 32434488       3421081     3421081   2977660   206209            13
#
#           orders_day_of_week  order_time  days_since_prior_order  product_id  \
# ...

# %%
# Checking the value counts of new merged dataframe
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### Exporting merged data as pickle

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
