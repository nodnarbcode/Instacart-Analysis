# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Importing Data

# %%
# Path assignment
path = r'C:\Users\nodnarb\Documents\IC Basket Analysis'

# %%
# Import orders products combined dataframe
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
# Ords_prods dimension check
df_ords_prods.shape
# Out:
# (32434489, 12)

# %%
# Import products dataframe
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %% [markdown]
# #### Dataframe check

# %%
# Ords_prods
df_ords_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_time  days_since_prior_order  product_id  \
# 0                   2           8                     0.0         196
# 1                   2           8                     0.0       14084
# 2                   2           8                     0.0       12427
# 3                   2           8                     0.0       26088
# 4                   2           8                     0.0       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# ...

# %%
# Products
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# #### Dataframe cleanup

# %%
# Dropping 1 column in prods dataframe
df_prods = df_prods.drop(columns = 'Unnamed: 0')

# %%
# Dropping 3 columns in ords_prods dataframe
df_ords_prods = df_ords_prods.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0', '_merge'])

# %% [markdown]
# #### Merging the two dataframes

# %%
df_orders_products_combined = df_ords_prods.merge(df_prods, on = ['product_id'], indicator = True)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# #### Exporting dataframe as pickle

# %%
df_orders_products_combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_orders_products_combined.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#          order_time  days_since_prior_order    product_id  add_to_cart_order  \
# count  3.240486e+07            3.240486e+07  3.240486e+07       3.240486e+07
# mean   1.342515e+01            1.039267e+01  2.559866e+04       8.352547e+00
# std    4.246380e+00            8.917825e+00  1.408400e+04       7.127071e+00
# ...
